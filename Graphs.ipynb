# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the data from the CSV file
penguins_data = pd.read_csv('penguins.csv')

# Create a scatter plot to visualize the relationship between penguin type, flipper length, and body mass
plt.figure(figsize=(12, 8))
sns.scatterplot(x='flipper_length_mm', y='body_mass_g', hue='species', data=penguins_data, palette='viridis', s=100)

# Customize the plot
plt.title('Relationship between Flipper Length, Body Mass, and Penguin Type')
plt.xlabel('Flipper Length (mm)')
plt.ylabel('Body Mass (g)')
plt.legend(title='Penguin Type')

# Show the plot
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the data from the CSV file
penguins_data = pd.read_csv('penguins.csv')

# Adelie Penguins
adelie_data = penguins_data[penguins_data['species'] == 'Adelie']

# Create scatter plot
plt.figure(figsize=(8, 6))
sns.scatterplot(x='flipper_length_mm', y='body_mass_g', data=adelie_data, s=100)
plt.title('Adelie Penguins: Relationship between Flipper Length and Body Mass')
plt.xlabel('Flipper Length (mm)')
plt.ylabel('Body Mass (g)')
plt.show()

# Chinstrap Penguins
chinstrap_data = penguins_data[penguins_data['species'] == 'Chinstrap']

# Create scatter plot
plt.figure(figsize=(8, 6))
sns.scatterplot(x='flipper_length_mm', y='body_mass_g', data=chinstrap_data, s=100)
plt.title('Chinstrap Penguins: Relationship between Flipper Length and Body Mass')
plt.xlabel('Flipper Length (mm)')
plt.ylabel('Body Mass (g)')
plt.show()

# Gentoo Penguins
gentoo_data = penguins_data[penguins_data['species'] == 'Gentoo']

# Create scatter plot
plt.figure(figsize=(8, 6))
sns.scatterplot(x='flipper_length_mm', y='body_mass_g', data=gentoo_data, s=100)
plt.title('Gentoo Penguins: Relationship between Flipper Length and Body Mass')
plt.xlabel('Flipper Length (mm)')
plt.ylabel('Body Mass (g)')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the data from the CSV file
penguins_data = pd.read_csv('penguins.csv')

# Create a bar plot to compare average body mass between species
plt.figure(figsize=(10, 6))
sns.barplot(x='species', y='body_mass_g', data=penguins_data, estimator='mean', ci='sd', palette='viridis', errorbar='sd')
plt.title('Comparison of Body Mass Between Penguin Species')
plt.xlabel('Penguin Species')
plt.ylabel('Body Mass (g)')
plt.show()
# Out:
# C:\Users\dadre\AppData\Local\Temp\ipykernel_28708\1693025901.py:10: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(x='species', y='body_mass_g', data=penguins_data, estimator='mean', ci='sd', palette='viridis', errorbar='sd')
# C:\Users\dadre\AppData\Local\Temp\ipykernel_28708\1693025901.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='species', y='body_mass_g', data=penguins_data, estimator='mean', ci='sd', palette='viridis', errorbar='sd')

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the data from the CSV file
penguins_data = pd.read_csv('penguins.csv')

# Create a bar plot to compare average body mass between species
plt.figure(figsize=(10, 6))
sns.barplot(x='species', y='flipper_length_mm', data=penguins_data, estimator='mean', ci='sd', palette='viridis', errorbar='sd')
plt.title('Comparison of Body Mass Between Penguin Species')
plt.xlabel('Penguin Species')
plt.ylabel('Flipper Length (mm)')
plt.show()
# Out:
# C:\Users\dadre\AppData\Local\Temp\ipykernel_28708\3778961857.py:10: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(x='species', y='flipper_length_mm', data=penguins_data, estimator='mean', ci='sd', palette='viridis', errorbar='sd')
# C:\Users\dadre\AppData\Local\Temp\ipykernel_28708\3778961857.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='species', y='flipper_length_mm', data=penguins_data, estimator='mean', ci='sd', palette='viridis', errorbar='sd')

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the data from the CSV file
penguins_data = pd.read_csv('penguins.csv')

# List of unique species in the dataset
species_list = penguins_data['species'].unique()

# Set up a grid for subplots
fig, axes = plt.subplots(nrows=1, ncols=len(species_list), figsize=(18, 6))

# Create separate scatter plots for each species
for i, species in enumerate(species_list):
    species_data = penguins_data[penguins_data['species'] == species]
    
    # Plot scatterplot by sex
    sns.scatterplot(x='flipper_length_mm', y='body_mass_g', hue='sex', data=species_data, palette='viridis', s=100, ax=axes[i])
    
    # Customize the plot
    axes[i].set_title(f'{species} Penguins: Flipper Length vs Body Mass by Sex')
    axes[i].set_xlabel('Flipper Length (mm)')
    axes[i].set_ylabel('Body Mass (g)')
    axes[i].legend(title='Sex')

# Adjust layout to prevent overlapping
plt.tight_layout()

# Show the combined plot
plt.show()
